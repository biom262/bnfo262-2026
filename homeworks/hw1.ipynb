# %% [markdown]
# # BNFO 262 / BIOM 262 / BGGN237 Winter 2026
#
# # Homework 1: Statistics and ChIP-seq

# %% [markdown]
# **Name**:
#
# **PID**:

# %% [markdown]
# ## Instructions
#
# Answer the following questions in your own words using a Jupyter notebook and upload a PDF of your answers to Gradescope. Make sure to write your name and PID at the start of your answers. This assignment is due on **Thursday, 01/29/2026 at 9:00AM**.

# %% [markdown]
# ### Part 0: (2 Points) Please make sure you select the correct pages for your answer to each question on Gradescope. You will get full points if you assign the pages correctly for all questions.

# %% [markdown]
# ## Part 1: Statistics (12 Points)

# %% [markdown]
# For this section, launch the stats DataHub environment
# ```ghcr.io/biom262/cmm262-notebook:stats```
#
# The following questions refer to the following file:
# ```~/public/hw1/colossus_pitch.csv```
#
# Note: you don’t need to copy over the file; you can just use the path above.
#
# For questions that require plotting and calculations, please include both your final answers and the code you used to obtain them. Submissions with answers only may not receive full credit.

# %% [markdown]
# ## Questions
#
# *Flora colossus* is a plant-like organism native to the planet X. This species is capable of human speech but their vocabulary consists solely of three words: "I", "am", and their name. It is thought that *F. colossus* can communicate a vast array of complex thoughts and expressions through the pitch and intonation of these three words, but an exact translation has not yet been thoroughly explored.
#
# In an attempt at decoding these rules, scientists asked an F. colossus named Groot to translate a set of 50 words carrying either a negative (neg) or positive (pos) connotation (conn). They recorded the responses to each word, and extracted the highest pitch from each response. Their data appears in the file ```colossus_pitch.csv```

# %%
# import the necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %%
# let's load the data into a dataframe named "df"
df = pd.read_csv("~/public/hw1/colossus_pitch.csv")

# %% [markdown]
# ### Q1 (3 points)

# %% [markdown]
# Plot two histograms for the pitches in response to 1) the negative words and 2) the positive words. Please label your axes. Based on the plots, do you think there is a significant difference between the two variables? Justify your reasoning.

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q2 (2 points)

# %% [markdown]
# Report the mean and standard deviation of the pitches for 1) the negative words and 2) the positive words.

# %% [markdown]
# ### Q3 (2 points)

# %% [markdown]
# The scientists think that *F. colossus* will respond with a lower pitch to words carrying a negative connotation and a higher pitch to words carrying a positive connotation. Use your results from the previous question to calculate a z-score and the p-value (using the ```stats.norm.cdf``` function) for this hypothesis. Under the threshold α=0.05, is this a significant result? Was the scientists’ hypothesis correct?

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q4 (2 points)

# %% [markdown]
# What would be the scientists’ hypothesis that makes a two-sided z-test appropriate? State the hypothesis, calculate a z-score and the p-value (using the stats.norm.cdf function) for this hypothesis. Under the threshold α=0.05, is this a significant result? Was the scientists’ hypothesis correct?

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q5 (3 points)

# %% [markdown]
# Let's say that we decided to use a t-test instead of a z-test. What kind of distribution are we assuming that the sample means (of the pitches) follow now? Are we now more or less likely to reject the null hypothesis? For full credit, please justify your response. Hint: sketch out the distributions on paper.

# %% [markdown]
# ANSWER:

# %% [markdown]
# ## Part 2: ChIP-seq (7 Points)

# %% [markdown]
# For this section, launch the ChIP-seq DataHub environment
# ```ghcr.io/biom262/cmm262-notebook:chipseq```
#
# Open a terminal and run ```source activate chipseq```
#
# The following questions refer to the following file:
# ```
# ~/public/hw1/hw-f1.bam
# ~/public/hw1/hw-f2.bam
# ```
# Note: you don’t need to copy over the file; you can just use the path above.

# %% [markdown]
# ### Q1 (2 points)

# %% [markdown]
# You received two BAM files from a colleague (hw-f1.bam and hw-f2.bam) but there was a mess up, and the files were not annotated properly. Which UNIX command(s) might you use to investigate which species the data was aligned to? Justify why your command(s) would work.

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q2 (1 point)

# %% [markdown]
# Find the two BAM files in the hw1 directory and then run your suggested commands from the previous question. Which species were the two BAM files aligned to?

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q3 (1 point)

# %% [markdown]
# What chromosome does the data in these two files come from? Note, some reads can align to multiple chromosomes, so make sure that your answer is not impacted by outlier reads.

# %% [markdown]
# ANSWER:

# %% [markdown]
# ### Q4 (3 points)

# %% [markdown]
# You were told that the two files are from a ChIP-seq experiment, and you are trying to figure out what is in each file: input or ChIP of DNA-binding protein. Which file is the input and which file comes from the ChIP-seq of the DNA-binding protein? What is the target protein/histone modification? Explain the steps you took and the commands that you used to reach this decision and add screenshots of any visualization tools. Hint: use two consecutive steps of the eleven in the ChIP-seq module.

# %% [markdown]
# ANSWER:
