# %% [markdown]
# # BNFO262 WI26 - Midterm
#
# ## Single Cell RNA-Sequencing

# %% [markdown]
# Name:
#
# Date:

# %% [markdown]
# ## Instructions
#
# Answer the following questions in your own words using a Jupyter notebook and attach a PDF of your code and written answers together in your Gradescope submission.
#
# * To run this notebook make sure to select the **scrna-seq env**: `ghcr.io/biom262/cmm262-notebook:scrna-seq`
#
# * Please write your code directly into this notebook. Add your written answers also directly into this notebook, in markdown cells.

# %%
# Import necessary packages
import scanpy as sc
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sns

# %% [markdown]
# ### Read in the data to a scanpy anndata object

# %%
adata = sc.read_10x_mtx('human_PBMCs', var_names='gene_symbols', cache=False)
adata

# %% [markdown]
# ### Question 1
#
# Take a quick look at your data with violin plots using scanpy’s built-in functions. (2 Points)
#
# A. Plot the number of counts per cell.
#
# B. Plot the number of genes per cell.

# %%
# Quality control - calculate QC covariates

# %%
# Plotting functions

# %% [markdown]
# ### Question 2
#
# Now, filter your dataset so that you are only left with (3 Points total):
#
# A. Cells that have at least 100 genes expressed in them
#
# B. Cells with a percent mitochondrial genes < 0.25
#
# C. Filter out any genes that are expressed below a count of 15
#
# **HINT: remember to calculate the percent_mito observation!**

# %%
print('Total number of starting cells: {:d}'.format(adata.n_obs))
print('Total number of starting genes: {:d}'.format(adata.n_vars))

# %%
# pull out mitochondrial genes and calculate the percent mito for each cell

# %%
# a.
# filter for cells with 100/+ genes

# %%
# b.
# filter for cells with <0.25 MT content

# %%
# c.
# filter for genes found in 15/+ cells

# %% [markdown]
# ### Question 3
#
# How many cells and genes do you have in your dataset’s adata object after Q6?

# %%
#

# %% [markdown]
# ### Question 4
#
# With our data filtered, perform several normalization steps on the data (3 Points total):
#
# A. Normalize the dataset for total counts per cell
#
# B. Log-transform the dataset
#
# C. Why is it important to normalize your data by total counts per cell?

# %%
# Store the raw counts in an additional layer

# %%
# a.

# %%
# b.

# %% [markdown]
# c.

# %% [markdown]
# ### Question 5
#
# Extract the highly variable genes from this dataset (2 Points total):
#
# A. Filter for genes with a minimum mean of 0.01, a maximum mean of 5, and a minimum dispersion of 0.20
#
# B. After this filtering step, how many genes do you have left in your dataset?

# %%
# a.

# %%
# b.

# %% [markdown]
# ### Question 6
# Why do we filter our dataset for highly variable genes?
